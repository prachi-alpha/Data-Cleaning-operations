# %%
#importing libraries for the further operations
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
from pandas import Int64Dtype

# %%
data=pd.read_excel('vendors.xlsx')
#to read excel file where data is stored
data.head()
#shows first 5 records of the data
# Out:
#           Name of Vendor   Contact No.  \
# 0          Shivaji D Pol  7.709215e+09
# 1     Varsha Shivaji Pol  7.066298e+09
# 2  Yogesh Ramchandra Pol  9.890667e+09
# 3        Aappaso Gaikwad  9.850817e+09
# 4                    NaN           NaN
#
#                                   Address    \
# 0  A/P Mardi,  Tal Man,  Dist Satara 415508
# 1             A/P Mardi Tal-Man Dist Satara
# 2                          A/P Mardi 415508
# 3                          A/p Mardi 415508
# 4                                       NaN
#
#                                           Resources
# 0  Tractor,trolly,nangar, dozer,front loader, tanker
# 1                                Fruit Plant Nursery
# 2                                Krushi Seva Kendra.
# 3                                         Kukutpalan
# 4                                                NaN

# %%
df=pd.read_excel( 'vendors.xlsx')
#to store data in dataframe named df

# %%
df
#print data in df
# Out:
#             Name of Vendor   Contact No.  \
# 0            Shivaji D Pol  7.709215e+09
# 1       Varsha Shivaji Pol  7.066298e+09
# 2    Yogesh Ramchandra Pol  9.890667e+09
# 3          Aappaso Gaikwad  9.850817e+09
# 4                      NaN           NaN
# 5                      NaN           NaN
# 6   Ramesh Vishanu Gaikwad  9.975159e+09
# 7     Mohan Dagadu Gaikwad  9.209312e+09
# 8      Sarjerao Dharmu Pol  9.699501e+09
# 9            Anil Nalawade  9.096530e+09
# 10            Rohit Dhavad  9.561215e+09
# 11        Shashikant Pawar  9.096005e+09
# 12        Shashikant Pawar  9.096005e+09
# 13        Shashikant Pawar  9.096005e+09
# 14              Yogesh Pol  9.096530e+09
# 15       Vaibhav Deshamukh  9.326841e+09
# 16               Amol Kale  9.588684e+09
# 17            Sunil Shelke  9.096006e+09
# 18            Sunil Shelke  9.096006e+09
# 19             Arun Shinde  9.175776e+09
# 20              Pramod Pol  9.766035e+09
# 21             Aashok kale  9.766532e+09
# ...

# %%
print(df.head())
#print first 5 records of df
# Out:
#           Name of Vendor   Contact No.  \
# 0          Shivaji D Pol  7.709215e+09
# 1     Varsha Shivaji Pol  7.066298e+09
# 2  Yogesh Ramchandra Pol  9.890667e+09
# 3        Aappaso Gaikwad  9.850817e+09
# 4                    NaN           NaN
#
#                                   Address    \
# 0  A/P Mardi,  Tal Man,  Dist Satara 415508
# 1             A/P Mardi Tal-Man Dist Satara
# 2                          A/P Mardi 415508
# 3                          A/p Mardi 415508
# 4                                       NaN
#
#                                           Resources
# 0  Tractor,trolly,nangar, dozer,front loader, tanker
# 1                                Fruit Plant Nursery
# 2                                Krushi Seva Kendra.
# 3                                         Kukutpalan
# 4                                                NaN

# %%
df2=df.copy()
df2
#copied data in dataframe df to another dataframe df2
# Out:
#             Name of Vendor   Contact No.  \
# 0            Shivaji D Pol  7.709215e+09
# 1       Varsha Shivaji Pol  7.066298e+09
# 2    Yogesh Ramchandra Pol  9.890667e+09
# 3          Aappaso Gaikwad  9.850817e+09
# 4                      NaN           NaN
# 5                      NaN           NaN
# 6   Ramesh Vishanu Gaikwad  9.975159e+09
# 7     Mohan Dagadu Gaikwad  9.209312e+09
# 8      Sarjerao Dharmu Pol  9.699501e+09
# 9            Anil Nalawade  9.096530e+09
# 10            Rohit Dhavad  9.561215e+09
# 11        Shashikant Pawar  9.096005e+09
# 12        Shashikant Pawar  9.096005e+09
# 13        Shashikant Pawar  9.096005e+09
# 14              Yogesh Pol  9.096530e+09
# 15       Vaibhav Deshamukh  9.326841e+09
# 16               Amol Kale  9.588684e+09
# 17            Sunil Shelke  9.096006e+09
# 18            Sunil Shelke  9.096006e+09
# 19             Arun Shinde  9.175776e+09
# 20              Pramod Pol  9.766035e+09
# 21             Aashok kale  9.766532e+09
# ...

# %%
df2.isnull().sum()
#check if the null records presents in df2
# Out:
# Name of Vendor    2
#  Contact No.      2
#  Address          2
# Resources         2
# dtype: int64

# %%
df2.dropna(how='any')
#remove the null records present in df2
# Out:
#             Name of Vendor   Contact No.  \
# 0            Shivaji D Pol  7.709215e+09
# 1       Varsha Shivaji Pol  7.066298e+09
# 2    Yogesh Ramchandra Pol  9.890667e+09
# 3          Aappaso Gaikwad  9.850817e+09
# 6   Ramesh Vishanu Gaikwad  9.975159e+09
# 7     Mohan Dagadu Gaikwad  9.209312e+09
# 8      Sarjerao Dharmu Pol  9.699501e+09
# 9            Anil Nalawade  9.096530e+09
# 10            Rohit Dhavad  9.561215e+09
# 11        Shashikant Pawar  9.096005e+09
# 12        Shashikant Pawar  9.096005e+09
# 13        Shashikant Pawar  9.096005e+09
# 14              Yogesh Pol  9.096530e+09
# 15       Vaibhav Deshamukh  9.326841e+09
# 16               Amol Kale  9.588684e+09
# 17            Sunil Shelke  9.096006e+09
# 18            Sunil Shelke  9.096006e+09
# 19             Arun Shinde  9.175776e+09
# 20              Pramod Pol  9.766035e+09
# 21             Aashok kale  9.766532e+09
# 22             Aashok kale  9.766532e+09
# 23              Tanaji Pol  9.766302e+09
# ...

# %%
df2.info()
#used to get information about non-null entries of column like index range, no, of columns, datatype etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name of Vendor  27 non-null     object
#  1    Contact No.    27 non-null     float64
#  2    Address        27 non-null     object
#  3   Resources       27 non-null     object
# dtypes: float64(1), object(3)
# memory usage: 1.0+ KB

# %%
df2.duplicated()
#applied to boolean series, FALSE : if duplicate values are not present, TRUE : if duplicate values are present
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27     True
# 28     True
# dtype: bool

# %%
df2=df2.drop_duplicates()
df2
#remove the duplicate records from dataframe
# Out:
#             Name of Vendor   Contact No.  \
# 0            Shivaji D Pol  7.709215e+09
# 1       Varsha Shivaji Pol  7.066298e+09
# 2    Yogesh Ramchandra Pol  9.890667e+09
# 3          Aappaso Gaikwad  9.850817e+09
# 4                      NaN           NaN
# 6   Ramesh Vishanu Gaikwad  9.975159e+09
# 7     Mohan Dagadu Gaikwad  9.209312e+09
# 8      Sarjerao Dharmu Pol  9.699501e+09
# 9            Anil Nalawade  9.096530e+09
# 10            Rohit Dhavad  9.561215e+09
# 11        Shashikant Pawar  9.096005e+09
# 12        Shashikant Pawar  9.096005e+09
# 13        Shashikant Pawar  9.096005e+09
# 14              Yogesh Pol  9.096530e+09
# 15       Vaibhav Deshamukh  9.326841e+09
# 16               Amol Kale  9.588684e+09
# 17            Sunil Shelke  9.096006e+09
# 18            Sunil Shelke  9.096006e+09
# 19             Arun Shinde  9.175776e+09
# 20              Pramod Pol  9.766035e+09
# 21             Aashok kale  9.766532e+09
# 22             Aashok kale  9.766532e+09
# ...

# %%
#data cleaned.
